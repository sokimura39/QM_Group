# %%
# start analysis here


import os
from urllib.request import urlopen
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import time

# files saved under Data/ActiveTravelCounts
dir = 'Data/ActiveTravelCounts'

counts_df = pd.read_parquet(os.path.join(dir, 'counts_cleaned.parquet'))

# %%
counts_df.sample(5)
# Out:
#         Year     UnqID  Zone            datetime        Date Weather  \
# 554261  2022  INNCY332     1 2022-07-19 11:15:00  19/07/2022     Dry
# 28756   2022  OUTCY013     2 2022-04-28 11:00:00  28/04/2022     Dry
# 76041   2022  OUTCY035     2 2022-05-25 08:15:00  25/05/2022     Dry
# 210280  2022  INNCY115     1 2022-06-28 16:00:00  28/06/2022     Dry
# 88392   2022  OUTCY041     2 2022-07-14 08:00:00  14/07/2022     Dry
#
#             Time      Day Round         Dir         Path                 Mode  \
# 554261  11:15:00  Weekday     A  Northbound     Pavement           E-scooters
# 28756   11:00:00  Weekday     A   Westbound   Cycle lane  Conventional cycles
# 76041   08:15:00  Weekday     A   Eastbound     Pavement          Cargo bikes
# 210280  16:00:00  Weekday     A   Eastbound     Pavement  Conventional cycles
# 88392   08:00:00  Weekday     A  Northbound  Carriageway  Conventional cycles
#
#         Count  isdry  ispeak  isCarriageway  isPavement  isCycle  isBus  \
# 554261      0      1       0              0           1        0      0
# 28756       1      1       0              0           0        1      0
# 76041       0      1       1              0           1        0      0
# 210280      0      1       0              0           1        0      0
# 88392       2      1       1              1           0        0      0
#
#         isShared
# 554261         0
# 28756          0
# 76041          0
# 210280         0
# 88392          0
